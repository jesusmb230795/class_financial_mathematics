# %% [markdown]
# # Initial Repository Setup
#
# Module: Setup and Python Ecosystem
#
# ## Lesson summary
#
# This notebook walks through the initial runtime checks for a freshly configured repository so students can confirm that Python, package versions, and notebook tooling are aligned.
#
# ## Learning objectives
# - Clone the supporting setup repository used in class.
# - Install the required Python packages from a requirements file.
# - Use `watermark` to document the runtime and package versions.
#
# ## Lesson flow
# 1. Clone the setup assets.
# 2. Install dependencies.
# 3. Record the environment versions for reproducibility.

# %% [markdown]
# ## Setup
#
# Run the terminal setup commands from the repository root, then open this notebook with the project kernel created by `uv`.

# %% [markdown]
# ## Terminal setup with pyenv and uv
#
# Run these commands from the repository root before opening JupyterLab. The project requires Python 3.12 or newer.
#
# ```bash
# pyenv install 3.12.12
# pyenv local 3.12.12
# uv sync
# uv run jupyter lab
# ```

# %% [markdown]
# ## Runtime check
#
# Run the following cells inside the `uv` environment to confirm that the active kernel is using Python 3.12 or newer.

# %%
import sys

print(sys.version)
assert sys.version_info >= (3, 12)

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w -p pandas,numpy,yfinance,fredapi,aleatory
